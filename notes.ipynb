# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/luki/Projects/frequency-shifter
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Users/luki/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from harmonic-frequency-shifter==0.1.0) (1.26.4)
# Requirement already satisfied: scipy>=1.11.0 in /Users/luki/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from harmonic-frequency-shifter==0.1.0) (1.16.3)
# Requirement already satisfied: soundfile>=0.12.0 in /Users/luki/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from harmonic-frequency-shifter==0.1.0) (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /Users/luki/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from soundfile>=0.12.0->harmonic-frequency-shifter==0.1.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/luki/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.0->harmonic-frequency-shifter==0.1.0) (2.23)
# Building wheels for collected packages: harmonic-frequency-shifter
#   Building editable for harmonic-frequency-shifter (pyproject.toml) ... done
#   Created wheel for harmonic-frequency-shifter: filename=harmonic_frequency_shifter-0.1.0-py3-none-any.whl size=6340 sha256=753e10e3148e08b239bd2dba0e3461350f4e2cfff18893e60e6ec64cef09b852
#   Stored in directory: /private/var/folders/cd/6lrk2wsd51bfnz1bq8mlk4zr0000gn/T/pip-ephem-wheel-cache-ygz892yi/wheels/ac/85/e0/fd311b685ec3d30c73deca137c97475faaba6511ea8ff0aa2f
# Successfully built harmonic-frequency-shifter
# Installing collected packages: harmonic-frequency-shifter
#   Attempting uninstall: harmonic-frequency-shifter
#     Found existing installation: harmonic-frequency-shifter 0.1.0
#     Uninstalling harmonic-frequency-shifter-0.1.0:
#       Successfully uninstalled harmonic-frequency-shifter-0.1.0
# Successfully installed harmonic-frequency-shifter-0.1.0

# %%
from harmonic_shifter import HarmonicShifter, load_audio, save_audio

# Initialize processor
processor = HarmonicShifter(
    sample_rate=44100,
    fft_size=4096,
    hop_size=1024
)

# Set musical scale
processor.set_scale(root_midi=60, scale_type='major')  # C major

# Load your audio file
audio, sr = load_audio('AURORA - When The Dark Dresses Lightly.wav')

# Process with frequency shift
output = processor.process(
    audio=audio,
    shift_hz=100,  # Shift up by 100 Hz
    quantize_strength=1.0  # Full quantization to scale
)

# Save the result
save_audio('output.wav', output, sample_rate=sr)
print("Done! Saved to output.wav")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from harmonic_shifter import HarmonicShifter, load_audio, save_audio
#       3 # Initialize processor
#       4 processor = HarmonicShifter(
#       5     sample_rate=44100,
#       6     fft_size=4096,
#       7     hop_size=1024
#       8 )
#
# ModuleNotFoundError: No module named 'harmonic_shifter'
